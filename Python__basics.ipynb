# %% [markdown]
# <a href="https://colab.research.google.com/github/rashmirashmi3038-ux/Python-basics/blob/main/Python__basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("rashmi")
# Out:
# rashmi

# %%
print ("hello world")
# Out:
# hello world

# %%
name="rashmi"
year="2008"

print("hello ",name)
print (year)
# Out:
# hello  rashmi
# 2008

# %%
,a=5
b=8
print (a+b)
print (a*b)
print (a-b)
print (a/b)
# Out:
# 13
# 40
# -3
# 0.625

# %%
a=10
b=5
print("add",a+b)
print ("mul",a*b)
print ("div",a/b)
# Out:
# add 15
# mul 50
# div 2.0

# %%
A=input("enter your name")
B=input ("enter your branch")
print ("hello",A)
print ("my branch is",B)
# Out:
# enter your nameRashmi
# enter your branchCSE
# hello Rashmi
# my branch is CSE

# %%
Age=int(input("enter your Age:"))

if Age>=18:
   print("you can vote")
else:
   print("come again next year")
# Out:
# enter your Age:20
# you can vote
