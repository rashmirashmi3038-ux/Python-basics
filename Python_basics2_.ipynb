# %% [markdown]
# <a href="https://colab.research.google.com/github/rashmirashmi3038-ux/Python-basics/blob/main/Python_basics2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks=int(input("enter your marks:"))
if marks>=50:
    print("you are pass")
else:
    Print("you are  fail")
# Out:
# enter your marks:50
# you are pass

# %%
def greet(name):
    print("hello",name)
greet("CSE")
greet("CSD")
greet("Civil")
# Out:
# hello CSE
# hello CSD
# hello Civil

# %%
def greet():
    print("hello")
greet()
# Out:
# hello
